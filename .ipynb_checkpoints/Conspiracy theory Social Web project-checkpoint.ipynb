# %% [markdown]
# # Project Social Web - Conspiracy theories

# %% [markdown]
# ## 1. Install and import packages

# %%
# !pip3 install -U textblob
# Out:
# Requirement already up-to-date: textblob in /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/site-packages (0.15.3)
# ...
# WARNING: You are using pip version 20.2.4; however, version 20.3.1 is available.
# You should consider upgrading via the '/Library/Frameworks/Python.framework/Versions/3.8/bin/python3.8 -m pip install --upgrade pip' command.

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import itertools
import collections

import tweepy as tw
import nltk
from nltk import bigrams
from nltk.corpus import stopwords
import re
import networkx as nx
from textblob import TextBlob

import warnings
warnings.filterwarnings("ignore")

sns.set(font_scale=1.5)
sns.set_style("whitegrid")

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/Yossigijrath/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %% [markdown]
# ## 2. Twitter setup

# %%
consumer_key = 'N4J4jiQuGW7DZKLvUXg1DUYlw'
consumer_secret = 'HwhmSr8rGqbzG9NlfaOSHl4No2RijgtJwtDCQEFNZ5vlSPzYbj'
access_token = '158063657-YJjxwBnlFS6GGn0jkhnqA6PIjzVRC9UhACSjCWrX'
access_token_secret = 'kuwpm8QnoNIX3bTkgOrlhjbdEKYxRiFqxqRXXRdLGeoJF'
auth = tw.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
# Define the search term as variables

#consipracy theories
plandemic_search = "#plandemic -filter:retweets"
electionfraud_search = "#electionfraud -filter:retweets"
flatearth_search = "#flatEarth -filter:retweets"
newworldorder_search = "#newworldorder -filter:retweets"
thegreatreset_search = "#thegreatreset -filter:retweets"
followthemoney_search = "#followthemoney  -filter:retweets"
epstein_search = "#epsteindidntkillhimself  -filter:retweets"

#regular hashtags
monday_search = "#MotivationMonday -filter:retweets"
tuesday_search = "#TransformationTuesday -filter:retweets"
wednesday_search = "#WednesdayWisdom -filter:retweets"
thursday_search = "#TBT -filter:retweets"
friday_search = "#FridayFeeling -filter:retweets"
saturday_search = "#Caturday -filter:retweets"
sunday_search = "#SundayFunday -filter:retweets"

#terms that will be used in a later stage
hashtag_word_reg = "regular hashtags"
hashtag_word_con = "conspiracy hashtags"
collection_words_conspiracy = ['plandemic', 'election', 'fraud', 'election' , 'electionfraud', 'flatearth' , 'flat', 'earth' , 'newworldorder' , 'new', 'world', 'order', 'the' , 'great' , 'reset', 'thegreatreset', 'followthemoney' , 'follow', 'money', 'epsteindidntkillhimself', 'epstein', 'didnt', 'kill', 'himself']
collection_words_regular = ['motivationmonday', 'transformationtuesday', 'wednesdaywisdom' , 'fridayfeeling' , 'sundayfunday' , 'motivation', 'monday', 'transformation', 'tuesday' , 'wednesday', 'wisdom' , 'tbt' , 'throwback' , 'thursday' , 'friday' , 'feeling' , 'caturday' , 'cat', 'saturday', 'sunday', 'funday']

# %% [markdown]
# ## 3. Twitter hashtag scrapping

# %% [markdown]
# We will scrape all consipracy hashtags and add them in different list. We will also create one big list where we will add all the consipracy tweets.

# %%
def twitter_scraper(search_word):
    tweets = tw.Cursor(api.search,
                   q=search_word,
                   lang="en",
                   since="2020-01-01").items(1000)

    all_tweets = [tweet.text for tweet in tweets]
    
    return all_tweets

# %% [markdown]
# ### 3.1 Conspiracy hashtags

# %%
# Collect tweets #plandemic
all_tweets_plandemic = twitter_scraper(plandemic_search)
print ('Total amount of tweets found: %s' %len(all_tweets_plandemic))
# Out:
# Total amount of tweets found: 1000

# %%
# Collect tweets #electionfraud
all_tweets_election = twitter_scraper(electionfraud_search)
print ('Total amount of tweets found: %s' %len(all_tweets_election))
# Out:
# Total amount of tweets found: 379

# %%
# Collect tweets #newworldorder
all_tweets_newworldorder = twitter_scraper(newworldorder_search)
print ('Total amount of tweets found: %s' %len(all_tweets_newworldorder))
# Out:
# Total amount of tweets found: 887

# %%
# Collect tweets #flatearth
all_tweets_flatearth = twitter_scraper(flatearth_search)
print ('Total amount of tweets found: %s' %len(all_tweets_flatearth))
# Out:
# Total amount of tweets found: 767

# %%
# Collect tweets #thegreatreset
all_tweets_thegreatreset = twitter_scraper(thegreatreset_search)
print ('Total amount of tweets found: %s' %len(all_tweets_thegreatreset))
# Out:
# Total amount of tweets found: 1000

# %%
# Collect tweets #followthemoney
all_tweets_followthemoney = twitter_scraper(followthemoney_search)
print ('Total amount of tweets found: %s' %len(all_tweets_followthemoney))
# Out:
# Total amount of tweets found: 1000

# %%
# Collect tweets #epsteindidntkillhimself
all_tweets_epstein = twitter_scraper(epstein_search)
print ('Total amount of tweets found: %s' %len(all_tweets_epstein))
# Out:
# Total amount of tweets found: 507

# %%
# Create list of all the conspiracy tweets
mega_tweet_list_conspiracy = all_tweets_flatearth + all_tweets_election + all_tweets_plandemic + all_tweets_newworldorder + all_tweets_thegreatreset + all_tweets_epstein + all_tweets_followthemoney
print("The total amount of tweets about conspiracy theories are:", len(mega_tweet_list_conspiracy))
# Out:
# The total amount of tweets about conspiracy theories are: 5540

# %% [markdown]
# ### 3.2 Regular hashtags

# %%
# Collect tweets #MotivationMonday
all_tweets_monday = twitter_scraper(monday_search)
print ('Total amount of tweets found: %s' %len(all_tweets_monday))
# Out:
# Total amount of tweets found: 1000

# %%
# Collect tweets #TransformationTuesday
all_tweets_tuesday = twitter_scraper(monday_search)
print ('Total amount of tweets found: %s' %len(all_tweets_tuesday))
# Out:
# Total amount of tweets found: 1000

# %%
# Collect tweets #WednesdayWisdom
all_tweets_wednesday = twitter_scraper(wednesday_search)
print ('Total amount of tweets found: %s' %len(all_tweets_wednesday))
# Out:
# Total amount of tweets found: 170

# %%
# Collect tweets #TBT
all_tweets_thursday = twitter_scraper(thursday_search)
print ('Total amount of tweets found: %s' %len(all_tweets_thursday))
# Out:
# Total amount of tweets found: 1000

# %%
# Collect tweets #FridayFeeling
all_tweets_friday = twitter_scraper(friday_search)
print ('Total amount of tweets found: %s' %len(all_tweets_friday))
# Out:
# Total amount of tweets found: 1000

# %%
# Collect tweets #Caturday
all_tweets_saturday = twitter_scraper(saturday_search)
print ('Total amount of tweets found: %s' %len(all_tweets_saturday))
# Out:
# Total amount of tweets found: 1000

# %%
# Collect tweets #SundayFunday
all_tweets_sunday = twitter_scraper(sunday_search)
print ('Total amount of tweets found: %s' %len(all_tweets_sunday))
# Out:
# Total amount of tweets found: 1000

# %%
# Create list of all the regular tweets
mega_list_regular_hashtags = all_tweets_monday + all_tweets_tuesday + all_tweets_wednesday + all_tweets_thursday + all_tweets_friday + all_tweets_saturday + all_tweets_sunday
print("The total amount of tweets about regular hashtags are: ", len(mega_list_regular_hashtags))
# Out:
# The total amount of tweets about regular hashtags are:  6170

# %% [markdown]
# ## 4. Pre-prossesing and cleaning

# %%
def remove_url(txt):
    """Replace URLs found in a text string with nothing 
    (i.e. it will remove the URL from the string).

    Parameters
    ----------
    txt : string
        A text string that you want to parse and remove urls.

    Returns
    -------
    The same txt string with url's removed.
    """

    return " ".join(re.sub("([^0-9A-Za-z \t])|(\w+:\/\/\S+)", "", txt).split())

# %%
def cleaning(hashtag_list, collection_word_type):
    
    # Remove URLs
    all_tweets_no_urls = [remove_url(tweet) for tweet in hashtag_list]

    # Create a sublist of lower case words for each tweet
    words_in_tweet = [tweet.lower().split() for tweet in all_tweets_no_urls]

    # Adding stopwords
    stop_words = set(stopwords.words('english'))

    # Remove stop words from each tweet list of words
    tweets_nsw = [[word for word in tweet_words if not word in stop_words]
              for tweet_words in words_in_tweet]

    # Remove collection words
    tweets_nsw_nc = [[w for w in word if not w in collection_word_type]
                 for word in tweets_nsw]
    
    return tweets_nsw_nc

# %% [markdown]
# ### 4.1 Cleaning and counting conspiracy hashtags

# %%
conspiracy_clean = cleaning(mega_tweet_list_conspiracy, collection_words_conspiracy)
all_words_conspiracy = list(itertools.chain(*conspiracy_clean))

# Create counter of words in clean tweets
conspiracy_word_count = collections.Counter(all_words_conspiracy)

# %% [markdown]
# ### 4.2 Cleaning and counting regular hashtags

# %%
regular_clean = cleaning(mega_list_regular_hashtags, collection_words_regular)
all_words_regular = list(itertools.chain(*regular_clean))

# Create counter of words in clean tweets
regular_word_count = collections.Counter(all_words_regular)

# %% [markdown]
# ## 5. Graph of most used words for given hashtag

# %% [markdown]
# ### 5.1 Conspiracy hashtags

# %%
clean_tweets_ncw = pd.DataFrame(conspiracy_word_count.most_common(20),
                             columns=['words', 'count'])

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_tweets_ncw.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="red")

ax.set_title("Common Words Found in Tweets on %s" % hashtag_word_con)

plt.ylabel('Words in Tweets')
plt.xlabel('Counter of words')
plt.show()

# %% [markdown]
# ### 5.2 Conspiracy hashtags

# %%
clean_tweets_ncw = pd.DataFrame(regular_word_count.most_common(20),
                             columns=['words', 'count'])

fig, ax = plt.subplots(figsize=(8, 8))

# Plot horizontal bar graph
clean_tweets_ncw.sort_values(by='count').plot.barh(x='words',
                      y='count',
                      ax=ax,
                      color="blue")

ax.set_title("Common Words Found in Tweets on %s" % hashtag_word_reg)

plt.ylabel('Words in Tweets')
plt.xlabel('Counter of words')
plt.show()

# %% [markdown]
# ## 6. Word bigrams and Network analysis

# %%
def bigram_and_network_maker(hashtag_clean_list):
    
    from nltk import bigrams

    terms_bigram = [list(bigrams(tweet)) for tweet in hashtag_clean_list]

    # Flatten list of bigrams in clean tweets
    bigrams = list(itertools.chain(*terms_bigram))

    # Create counter of words in clean bigrams
    bigram_counts = collections.Counter(bigrams)
    bigram_df = pd.DataFrame(bigram_counts.most_common(100), columns=['bigram', 'count'])
    
    # Create dictionary of bigrams and their counts
    d = bigram_df.set_index('bigram').T.to_dict('records')

    # Create network plot 
    G = nx.Graph()

    # Create connections between nodes
    for k, v in d[0].items():
        G.add_edge(k[0], k[1], weight=(v * 10))
        
    return G

# %% [markdown]
# ### 6.1 Bigram maker on conspiracy hashtags

# %%
conspiracy_network = bigram_and_network_maker(conspiracy_clean)

# %%
fig, ax = plt.subplots(figsize=(10, 8))

pos = nx.spring_layout(conspiracy_network, k=2)

# Plot networks
nx.draw_networkx(conspiracy_network, pos,
                 font_size=5,
                 width=1,
                 edge_color='grey',
                 node_color='red',
                 with_labels = False,
                 ax=ax)

# Create offset labels
for key, value in pos.items():
    x, y = value[0]+.135, value[1]+.045
    ax.text(x, y,
            s=key,
            bbox=dict(facecolor='blue', alpha=0.25),
            horizontalalignment='center', fontsize=10)
    
plt.title("Bigrams and Network analysis on %s" % hashtag_word_con)    
plt.show()

# %% [markdown]
# ### 6.2 Bigram maker on regular hashtags

# %%
regular_network = bigram_and_network_maker(regular_clean)

# %%
fig, ax = plt.subplots(figsize=(10, 8))

pos = nx.spring_layout(regular_network, k=2)

# Plot networks
nx.draw_networkx(regular_network, pos,
                 font_size=5,
                 width=1,
                 edge_color='grey',
                 node_color='blue',
                 with_labels = False,
                 ax=ax)

# Create offset labels
for key, value in pos.items():
    x, y = value[0]+.135, value[1]+.045
    ax.text(x, y,
            s=key,
            bbox=dict(facecolor='red', alpha=0.25),
            horizontalalignment='center', fontsize=10)
    
plt.title("Bigrams and Network analysis on %s" % hashtag_word_reg)    
plt.show()

# %% [markdown]
# ## 7. Sentiment analysis

# %%
def sentiment_analist(hashtag_list):
    
    # Remove URLs
    all_tweets_no_urls = [remove_url(tweet) for tweet in hashtag_list]

    # Create textblob objects of the tweets
    sentiment_objects = [TextBlob(tweet) for tweet in all_tweets_no_urls]

    # Create list of polarity valuesx and tweet text
    sentiment_values = [[tweet.sentiment.polarity, str(tweet)] for tweet in sentiment_objects]

    # Create dataframe containing the polarity value and tweet text
    sentiment_df = pd.DataFrame(sentiment_values, columns=["polarity", "tweet"])

    # Remove polarity values equal to zero
    sentiment_df = sentiment_df[sentiment_df.polarity != 0]
    
    return sentiment_df

# %% [markdown]
# ### 7.1 Sentiment analysis on conspiracy hashtags

# %%
conspiracy_sentiment = sentiment_analist(mega_tweet_list_conspiracy)

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot histogram with break at zero
conspiracy_sentiment.hist(bins=[-1, -0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.75, 1], 
                ax=ax,
                color="red")

plt.title("Sentiments from Tweets on %s" % hashtag_word_con)
plt.xlabel('Sentiment score')
plt.ylabel('Number of Tweets')
plt.show()

# %% [markdown]
# ### 7.2 Sentiment analysis on regular hashtags

# %%
regular_sentiment = sentiment_analist(mega_list_regular_hashtags)

# %%
fig, ax = plt.subplots(figsize=(8, 6))

# Plot histogram with break at zero
regular_sentiment.hist(bins=[-1, -0.75, -0.5, -0.25, 0.0, 0.25, 0.5, 0.75, 1], 
                ax=ax,
                color="blue")

plt.title("Sentiments from Tweets on %s" % hashtag_word_reg)
plt.xlabel('Sentiment score')
plt.ylabel('Number of Tweets')
plt.show()
